# %% [markdown]
# ## Part 1: Setting Up
#
# ✨This is a Jupyter Notebook that allows you to run Python code interactively 🐍✨
#
# 🚨**Double click on the notebook tab** above to keep the notebook open!
#
# 1. Click the **Select Kernel** button on the top right of the notebook.
# 2. Choose **Python environments** and select **Python 3.11**.
#
# Note: To run the code in the cells of this notebook click the play button (▶️) on the left side of the cells that contain code.
#
# These are instructions for the insructor led sessions, you should have the Skillable Lab Manual open in a different tab.
#
# Copy/Paste the `CREDENTIALS` block at the top of the Skillable Lab instructions into the cell below:

# %%
# CREDENTIALS
Username     = "Username"

Password     = "Password"

AzureEnvName = "OnderEnv2"

Subscription = "Subscription"

# %% [markdown]
# ### a. Login to GitHub.com and fork repository
#
# We'll begin by logging into the Github CLI so we can fork the repository and make changes to the code comfortably.

# %% [markdown]
# > Running this command will:
# >   - Log in to the **GitHub.com** account
# >   - Select **HTTPS** as the preferred protocol for Git operations
# >   - Authenticate Git with your GitHub credentials
# >   - Authenticate GitHub CLI using **a web browser**
#
# Click the play button to the left of the cell to run it and then complete the authorization process.

# %%
! echo Y | GITHUB_TOKEN="" gh auth login --hostname github.com --git-protocol https --web --scopes workflow
# Out:
# ! First copy your one-time code: 25D9-8891
# Open this URL to continue in your web browser: https://github.com/login/device
# ✓ Authentication complete.
# - gh config set -h github.com git_protocol https
# ✓ Configured git protocol
# ! Authentication credentials saved in plain text
# ✓ Logged in as onderyildirim

# %% [markdown]
# Then fork the repository

# %%
! GITHUB_TOKEN="" gh repo fork --remote
# Out:
# ✓ Created fork onderyildirim/contoso-creative-writer
# ✓ Added remote origin

# %% [markdown]
# ### b. Login to Azure
#
# We will login to Azure Developer CLI (azd) and Azure CLI (az).
#
# 1. Sign in to Azure Developer CLI (azd)

# %%
! echo $'\n'   | az login --use-device-code
# Out:
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code B6U4623QM to authenticate.
# [
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "id": "8f036be0-cafa-442a-b8ca-0e1269454f60",
#     "isDefault": true,
#     "managedByTenants": [
#       {
#         "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47"
#       }
#     ],
#     "name": "ME-MngEnvMCAP507582-ondery-3",
#     "state": "Enabled",
#     "tenantDefaultDomain": "MngEnvMCAP507582.onmicrosoft.com",
#     "tenantDisplayName": "Contoso",
#     "tenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "user": {
#       "name": "admin@MngEnvMCAP507582.onmicrosoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "id": "9e2ebc38-5636-4de5-904a-61ca32225053",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47"
#       }
#     ],
#     "name": "ME-MngEnvMCAP507582-ondery-9",
#     "state": "Enabled",
#     "tenantDefaultDomain": "MngEnvMCAP507582.onmicrosoft.com",
#     "tenantDisplayName": "Contoso",
#     "tenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "user": {
#       "name": "admin@MngEnvMCAP507582.onmicrosoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "id": "cd3c8058-9088-4320-845d-67ac1eb65129",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47"
#       }
#     ],
#     "name": "ME-MngEnvMCAP507582-ondery-8",
#     "state": "Enabled",
#     "tenantDefaultDomain": "MngEnvMCAP507582.onmicrosoft.com",
#     "tenantDisplayName": "Contoso",
#     "tenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "user": {
#       "name": "admin@MngEnvMCAP507582.onmicrosoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "id": "2cf727f5-512a-4b90-83fd-78bb63879e37",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47"
#       }
#     ],
#     "name": "ME-MngEnvMCAP507582-ondery-7",
#     "state": "Enabled",
#     "tenantDefaultDomain": "MngEnvMCAP507582.onmicrosoft.com",
#     "tenantDisplayName": "Contoso",
#     "tenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "user": {
#       "name": "admin@MngEnvMCAP507582.onmicrosoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "id": "84835fc1-156c-49a5-98fa-8170a8e4a92c",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47"
#       }
#     ],
#     "name": "ME-MngEnvMCAP507582-ondery-6",
#     "state": "Enabled",
#     "tenantDefaultDomain": "MngEnvMCAP507582.onmicrosoft.com",
#     "tenantDisplayName": "Contoso",
#     "tenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "user": {
#       "name": "admin@MngEnvMCAP507582.onmicrosoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "id": "16ae5a9b-d114-4bfa-9139-8765bc116e7f",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47"
#       }
#     ],
#     "name": "ME-MngEnvMCAP507582-ondery-2",
#     "state": "Enabled",
#     "tenantDefaultDomain": "MngEnvMCAP507582.onmicrosoft.com",
#     "tenantDisplayName": "Contoso",
#     "tenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "user": {
#       "name": "admin@MngEnvMCAP507582.onmicrosoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "id": "9efe1d6c-8fb1-46aa-979b-9ee6806b2765",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47"
#       }
#     ],
#     "name": "ME-MngEnvMCAP507582-ondery-1",
#     "state": "Enabled",
#     "tenantDefaultDomain": "MngEnvMCAP507582.onmicrosoft.com",
#     "tenantDisplayName": "Contoso",
#     "tenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "user": {
#       "name": "admin@MngEnvMCAP507582.onmicrosoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "id": "234d7503-1086-4f11-9a43-c7d792711898",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47"
#       }
#     ],
#     "name": "ME-MngEnvMCAP507582-ondery-5",
#     "state": "Enabled",
#     "tenantDefaultDomain": "MngEnvMCAP507582.onmicrosoft.com",
#     "tenantDisplayName": "Contoso",
#     "tenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "user": {
#       "name": "admin@MngEnvMCAP507582.onmicrosoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "id": "17cecf09-1ad3-4bf2-a084-e97f47fdbf55",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47"
#       }
#     ],
#     "name": "ME-MngEnvMCAP507582-ondery-10",
#     "state": "Enabled",
#     "tenantDefaultDomain": "MngEnvMCAP507582.onmicrosoft.com",
#     "tenantDisplayName": "Contoso",
#     "tenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "user": {
#       "name": "admin@MngEnvMCAP507582.onmicrosoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "id": "0a42f2f8-ae2f-458d-9e12-f85cb03b96da",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47"
#       }
#     ],
#     "name": "ME-MngEnvMCAP507582-ondery-4",
#     "state": "Enabled",
#     "tenantDefaultDomain": "MngEnvMCAP507582.onmicrosoft.com",
#     "tenantDisplayName": "Contoso",
#     "tenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "user": {
#       "name": "admin@MngEnvMCAP507582.onmicrosoft.com",
#       "type": "user"
#     }
#   }
# ]

# %%
! az login --use-device-code <<< "\n"
# Out:
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code EAXZ3HKAF to authenticate.
# [
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "id": "8f036be0-cafa-442a-b8ca-0e1269454f60",
#     "isDefault": true,
#     "managedByTenants": [
#       {
#         "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47"
#       }
#     ],
#     "name": "ME-MngEnvMCAP507582-ondery-3",
#     "state": "Enabled",
#     "tenantDefaultDomain": "MngEnvMCAP507582.onmicrosoft.com",
#     "tenantDisplayName": "Contoso",
#     "tenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "user": {
#       "name": "admin@MngEnvMCAP507582.onmicrosoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "id": "9e2ebc38-5636-4de5-904a-61ca32225053",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47"
#       }
#     ],
#     "name": "ME-MngEnvMCAP507582-ondery-9",
#     "state": "Enabled",
#     "tenantDefaultDomain": "MngEnvMCAP507582.onmicrosoft.com",
#     "tenantDisplayName": "Contoso",
#     "tenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "user": {
#       "name": "admin@MngEnvMCAP507582.onmicrosoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "id": "cd3c8058-9088-4320-845d-67ac1eb65129",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47"
#       }
#     ],
#     "name": "ME-MngEnvMCAP507582-ondery-8",
#     "state": "Enabled",
#     "tenantDefaultDomain": "MngEnvMCAP507582.onmicrosoft.com",
#     "tenantDisplayName": "Contoso",
#     "tenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "user": {
#       "name": "admin@MngEnvMCAP507582.onmicrosoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "id": "2cf727f5-512a-4b90-83fd-78bb63879e37",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47"
#       }
#     ],
#     "name": "ME-MngEnvMCAP507582-ondery-7",
#     "state": "Enabled",
#     "tenantDefaultDomain": "MngEnvMCAP507582.onmicrosoft.com",
#     "tenantDisplayName": "Contoso",
#     "tenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "user": {
#       "name": "admin@MngEnvMCAP507582.onmicrosoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "id": "84835fc1-156c-49a5-98fa-8170a8e4a92c",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47"
#       }
#     ],
#     "name": "ME-MngEnvMCAP507582-ondery-6",
#     "state": "Enabled",
#     "tenantDefaultDomain": "MngEnvMCAP507582.onmicrosoft.com",
#     "tenantDisplayName": "Contoso",
#     "tenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "user": {
#       "name": "admin@MngEnvMCAP507582.onmicrosoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "id": "16ae5a9b-d114-4bfa-9139-8765bc116e7f",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47"
#       }
#     ],
#     "name": "ME-MngEnvMCAP507582-ondery-2",
#     "state": "Enabled",
#     "tenantDefaultDomain": "MngEnvMCAP507582.onmicrosoft.com",
#     "tenantDisplayName": "Contoso",
#     "tenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "user": {
#       "name": "admin@MngEnvMCAP507582.onmicrosoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "id": "9efe1d6c-8fb1-46aa-979b-9ee6806b2765",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47"
#       }
#     ],
#     "name": "ME-MngEnvMCAP507582-ondery-1",
#     "state": "Enabled",
#     "tenantDefaultDomain": "MngEnvMCAP507582.onmicrosoft.com",
#     "tenantDisplayName": "Contoso",
#     "tenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "user": {
#       "name": "admin@MngEnvMCAP507582.onmicrosoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "id": "234d7503-1086-4f11-9a43-c7d792711898",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47"
#       }
#     ],
#     "name": "ME-MngEnvMCAP507582-ondery-5",
#     "state": "Enabled",
#     "tenantDefaultDomain": "MngEnvMCAP507582.onmicrosoft.com",
#     "tenantDisplayName": "Contoso",
#     "tenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "user": {
#       "name": "admin@MngEnvMCAP507582.onmicrosoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "id": "17cecf09-1ad3-4bf2-a084-e97f47fdbf55",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47"
#       }
#     ],
#     "name": "ME-MngEnvMCAP507582-ondery-10",
#     "state": "Enabled",
#     "tenantDefaultDomain": "MngEnvMCAP507582.onmicrosoft.com",
#     "tenantDisplayName": "Contoso",
#     "tenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "user": {
#       "name": "admin@MngEnvMCAP507582.onmicrosoft.com",
#       "type": "user"
#     }
#   },
#   {
#     "cloudName": "AzureCloud",
#     "homeTenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "id": "0a42f2f8-ae2f-458d-9e12-f85cb03b96da",
#     "isDefault": false,
#     "managedByTenants": [
#       {
#         "tenantId": "72f988bf-86f1-41af-91ab-2d7cd011db47"
#       }
#     ],
#     "name": "ME-MngEnvMCAP507582-ondery-4",
#     "state": "Enabled",
#     "tenantDefaultDomain": "MngEnvMCAP507582.onmicrosoft.com",
#     "tenantDisplayName": "Contoso",
#     "tenantId": "84a9d715-5b07-468e-b164-e812f5e0a104",
#     "user": {
#       "name": "admin@MngEnvMCAP507582.onmicrosoft.com",
#       "type": "user"
#     }
#   }
# ]

# %% [markdown]
# 2. Sign in to Azure Developer CLI.
#
#     > **🚨 IMPORTANT**: Use the following `username` and `password` when prompted to sign in with an email and password.

# %%
! az account set -s ME-MngEnvMCAP507582-ondery-1

# %%
from IPython.display import Markdown
Markdown(f"- **Username**: `{Username}`\n - **Password**: `{Password}`")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 from IPython.display import Markdown
# ----> 2 Markdown(f"- **Username**: `{Username}`\n - **Password**: `{Password}`")
#
# NameError: name 'Username' is not defined

# %%
! azd auth login --use-device-code --no-prompt
# Out:
# Start by copying the next code: EJ4LMN272
# Then, go to: https://microsoft.com/devicelogin
# Waiting for you to complete authentication in the browser...
# Device code authentication completed.
# Logged in to Azure.ing subscriptions...

# %% [markdown]
# ### c. Get environment variables (You will need to use the terminal for step 1!)
#
# 1. Next we will get the environment variables for your resource group.
#
#     > **🚨 IMPORTANT: You will need to run the output of the next cell in the terminal!**
#     >
#     > - Run the cell below and then copy the output and paste it in the terminal and press enter
#     > - Select `Y` when asked if you'd like to create the environment
#     > - Press enter to select the default subscription
#     > - Select `Canada East` as the location
#
#     > **It's important that you select the correct location (Canada East)**

# %%
from IPython.display import Markdown
Markdown(f"azd env refresh -e {AzureEnvName}")
# Out:
# azd env refresh -e OnderEnv

# %% [markdown]
# Once the command has been successfully run, continue with step 4, running the cells in the notebook as before.

# %% [markdown]
# 4. Save the environment variables to a .env file.

# %%
! azd env get-values > ../../.env

# %% [markdown]
# The refreshed environment variables should have been saved to the [.env](../../.env)

# %% [markdown]
# 5. Set the correct roles by running the roles bash script.

# %%
! bash ../../infra/hooks/roles.sh
# Out:
# {
#   "condition": null,
#   "conditionVersion": null,
#   "createdBy": "10bb6909-b305-4113-997a-e9a4469c3086",
#   "createdOn": "2024-11-26T17:25:09.314164+00:00",
#   "delegatedManagedIdentityResourceId": null,
#   "description": null,
#   "id": "/subscriptions/9efe1d6c-8fb1-46aa-979b-9ee6806b2765/resourcegroups/rg-OnderEnv2/providers/Microsoft.Authorization/roleAssignments/382c9eab-658b-51af-8faa-bb9533de8e1e",
#   "name": "382c9eab-658b-51af-8faa-bb9533de8e1e",
#   "principalId": "10bb6909-b305-4113-997a-e9a4469c3086",
#   "principalName": "admin@MngEnvMCAP507582.onmicrosoft.com",
#   "principalType": "User",
#   "resourceGroup": "rg-OnderEnv2",
#   "roleDefinitionId": "/subscriptions/9efe1d6c-8fb1-46aa-979b-9ee6806b2765/providers/Microsoft.Authorization/roleDefinitions/8ebe5a00-799e-43f5-93ac-243d3dce84a7",
#   "roleDefinitionName": "Search Index Data Contributor",
#   "scope": "/subscriptions/9efe1d6c-8fb1-46aa-979b-9ee6806b2765/resourcegroups/rg-OnderEnv2",
#   "type": "Microsoft.Authorization/roleAssignments",
#   "updatedBy": "10bb6909-b305-4113-997a-e9a4469c3086",
#   "updatedOn": "2024-11-26T17:59:20.574408+00:00"
# }
# {
#   "condition": null,
#   "conditionVersion": null,
#   "createdBy": "10bb6909-b305-4113-997a-e9a4469c3086",
#   "createdOn": "2024-11-26T17:25:09.319008+00:00",
#   "delegatedManagedIdentityResourceId": null,
#   "description": null,
#   "id": "/subscriptions/9efe1d6c-8fb1-46aa-979b-9ee6806b2765/resourcegroups/rg-OnderEnv2/providers/Microsoft.Authorization/roleAssignments/70aff9fa-dbb4-5e13-9450-6a766c47c5ca",
#   "name": "70aff9fa-dbb4-5e13-9450-6a766c47c5ca",
#   "principalId": "10bb6909-b305-4113-997a-e9a4469c3086",
#   "principalName": "admin@MngEnvMCAP507582.onmicrosoft.com",
#   "principalType": "User",
#   "resourceGroup": "rg-OnderEnv2",
#   "roleDefinitionId": "/subscriptions/9efe1d6c-8fb1-46aa-979b-9ee6806b2765/providers/Microsoft.Authorization/roleDefinitions/1407120a-92aa-4202-b7e9-c0e197c71c8f",
#   "roleDefinitionName": "Search Index Data Reader",
#   "scope": "/subscriptions/9efe1d6c-8fb1-46aa-979b-9ee6806b2765/resourcegroups/rg-OnderEnv2",
#   "type": "Microsoft.Authorization/roleAssignments",
#   "updatedBy": "10bb6909-b305-4113-997a-e9a4469c3086",
#   "updatedOn": "2024-11-26T17:59:20.046772+00:00"
# }
# {
#   "condition": null,
#   "conditionVersion": null,
#   "createdBy": "10bb6909-b305-4113-997a-e9a4469c3086",
#   "createdOn": "2024-11-26T17:25:09.233752+00:00",
#   "delegatedManagedIdentityResourceId": null,
#   "description": null,
#   "id": "/subscriptions/9efe1d6c-8fb1-46aa-979b-9ee6806b2765/resourcegroups/rg-OnderEnv2/providers/Microsoft.Authorization/roleAssignments/e20915e1-ad45-508d-aafc-3b3dea186371",
#   "name": "e20915e1-ad45-508d-aafc-3b3dea186371",
#   "principalId": "10bb6909-b305-4113-997a-e9a4469c3086",
#   "principalName": "admin@MngEnvMCAP507582.onmicrosoft.com",
#   "principalType": "User",
#   "resourceGroup": "rg-OnderEnv2",
#   "roleDefinitionId": "/subscriptions/9efe1d6c-8fb1-46aa-979b-9ee6806b2765/providers/Microsoft.Authorization/roleDefinitions/5e0bd9bd-7b93-4f28-af87-19fc36ad61bd",
#   "roleDefinitionName": "Cognitive Services OpenAI User",
#   "scope": "/subscriptions/9efe1d6c-8fb1-46aa-979b-9ee6806b2765/resourcegroups/rg-OnderEnv2",
#   "type": "Microsoft.Authorization/roleAssignments",
#   "updatedBy": "10bb6909-b305-4113-997a-e9a4469c3086",
#   "updatedOn": "2024-11-26T17:59:19.255143+00:00"
# }

# %% [markdown]
# 6. Run the postprovision script by running the cell below
#     - This script will take about 3 mins to run.

# %%
! echo 1 | azd hooks run postprovision -e $AzureEnvName
# Out:
# Running hooks (azd hooks run)
# Finding and executing postprovision hooks for environment OnderEnv2.
#
# Running 1 postprovision command hook(s) for project
#   Running 1 postprovision command hook(s) for project
#
#   ──── Project: postprovision Hook Output ──────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
# ─────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#   --- ✅ | 1. Post-provisioning - env configured ---
#
# ─────────────────────────────────────────────────────────────────────
#
#
#
#
#
#   --- ✅ | 1. Post-provisioning - env configured ---
#   Installing dependencies from "requirements.txt"
#
# ─────────────────────────────────────────────────────────────────────
#
#
#
#
#   --- ✅ | 1. Post-provisioning - env configured ---
#   Installing dependencies from "requirements.txt"
#   --- ✅ | 2. Post-provisioning - ready execute notebooks ---
#
# ─────────────────────────────────────────────────────────────────────
#
#
#
#   --- ✅ | 1. Post-provisioning - env configured ---
#   Installing dependencies from "requirements.txt"
#   --- ✅ | 2. Post-provisioning - ready execute notebooks ---
#   Populating data ....
#
# ─────────────────────────────────────────────────────────────────────
#
#
#   --- ✅ | 1. Post-provisioning - env configured ---
#   Installing dependencies from "requirements.txt"
#   --- ✅ | 2. Post-provisioning - ready execute notebooks ---
#   Populating data ....
#   --- ✅ | 3. Post-provisioning - populated data ---
#
# ─────────────────────────────────────────────────────────────────────
#   --- ✅ | 1. Post-provisioning - env configured ---
#   Installing dependencies from "requirements.txt"
#   --- ✅ | 2. Post-provisioning - ready execute notebooks ---
#   Populating data ....
#   --- ✅ | 3. Post-provisioning - populated data ---
#   --- 🎉 | 4. Access your ACA deployed web app here: https://agent-web.thankfu
#   lbay-cbff7b80.canadaeast.azurecontainerapps.io
#
#   (✓) Done: Running 1 postprovision command hook(s) for project─────
# Running 0 postprovision service hook(s) for api
#   (!) Warning: Running 0 postprovision service hook(s) for api (No hook found)
# Running 0 postprovision service hook(s) for web
#   (!) Warning: Running 0 postprovision service hook(s) for web (No hook found)
#
# SUCCESS: Your hooks have been run successfully

# %% [markdown]
# You are now ready to start understanding and building Contoso Creative Writer!
#
# ## Part 2: Understanding and Building Contoso Creative Writer
#
# ### Learning Outcomes
# In this section we will focus on four key outcomes, each split into their own notebook:
#
# 1. [Understanding agents and prompt engineering with Prompty.](./workshop-1-intro.ipynb)
# 2. [Utilizing Prompty tracing for debugging and observability.](./workshop-2-tracing.ipynb)
# 3. [Building and running Contoso Creative Writer.](./workshop-3-build.ipynb)
# 4. [Setting up automated evaluations with GitHub Actions.](./workshop-4-ci-cd.ipynb)
#
# Open the [workshop-1-intro.ipynb](workshop-1-intro.ipynb) file to begin the first learning outcome!
